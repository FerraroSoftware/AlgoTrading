# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import cufflinks as cf
from pandas_datareader import data
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
start = "2018-01-01"
end = "2021-05-31"
symbol = "AAPL"

# %%
df = data.DataReader(name=symbol, data_source="yahoo",start=start,end=end)
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-01-02   43.075001   42.314999   42.540001   43.064999  102223600.0
# 2018-01-03   43.637501   42.990002   43.132500   43.057499  118071600.0
# 2018-01-04   43.367500   43.020000   43.134998   43.257500   89738400.0
# 2018-01-05   43.842499   43.262501   43.360001   43.750000   94640000.0
# 2018-01-08   43.902500   43.482498   43.587502   43.587502   82271200.0
# ...                ...         ...         ...         ...          ...
# 2021-05-24  127.940002  125.940002  126.010002  127.099998   63092900.0
# 2021-05-25  128.320007  126.320000  127.820000  126.900002   72009500.0
# 2021-05-26  127.389999  126.419998  126.959999  126.849998   56575900.0
# 2021-05-27  127.639999  125.080002  126.440002  125.279999   94625600.0
# 2021-05-28  125.800003  124.550003  125.570000  124.610001   71311100.0
#
#              Adj Close
# Date
# 2018-01-02   41.310070
# 2018-01-03   41.302879
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 858 entries, 2018-01-02 to 2021-05-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       858 non-null    float64
#  1   Low        858 non-null    float64
#  2   Open       858 non-null    float64
#  3   Close      858 non-null    float64
#  4   Volume     858 non-null    float64
#  5   Adj Close  858 non-null    float64
# dtypes: float64(6)
# memory usage: 46.9 KB

# %%
df.Close
# Out:
# Date
# 2018-01-02     43.064999
# 2018-01-03     43.057499
# 2018-01-04     43.257500
# 2018-01-05     43.750000
# 2018-01-08     43.587502
#                  ...
# 2021-05-24    127.099998
# 2021-05-25    126.900002
# 2021-05-26    126.849998
# 2021-05-27    125.279999
# 2021-05-28    124.610001
# Name: Close, Length: 858, dtype: float64

# %%
df.Close.plot(figsize=(12,8))
plt.show()

# %%
df.loc["2021"].Close.plot(figsize=(12,8))
plt.show()

# %%
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.loc["2021"].Close.iplot()
# Out:
# <div>                            <div id="faa6865f-b98e-4c13-b7ae-b4cdcf0c9214" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot()
# Out:
# <div>                            <div id="922b3bc6-051e-42a9-90ef-b04e090d6e23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-01-02   43.075001   42.314999   42.540001   43.064999  102223600.0
# 2018-01-03   43.637501   42.990002   43.132500   43.057499  118071600.0
# 2018-01-04   43.367500   43.020000   43.134998   43.257500   89738400.0
# 2018-01-05   43.842499   43.262501   43.360001   43.750000   94640000.0
# 2018-01-08   43.902500   43.482498   43.587502   43.587502   82271200.0
# ...                ...         ...         ...         ...          ...
# 2021-05-24  127.940002  125.940002  126.010002  127.099998   63092900.0
# 2021-05-25  128.320007  126.320000  127.820000  126.900002   72009500.0
# 2021-05-26  127.389999  126.419998  126.959999  126.849998   56575900.0
# 2021-05-27  127.639999  125.080002  126.440002  125.279999   94625600.0
# 2021-05-28  125.800003  124.550003  125.570000  124.610001   71311100.0
#
#              Adj Close
# Date
# 2018-01-02   41.310070
# 2018-01-03   41.302879
# ...

# %%
df.loc["2021"].iplot(kind="candle")
# Out:
# <div>                            <div id="79362fb8-11a2-4813-82dc-e4975e3931a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
qf = cf.QuantFig(df=df.loc["2021"])

# %%
qf.iplot(name="APPL")
# Out:
# <div>                            <div id="3e2bf4e2-35e8-4fba-968a-68300d86b77f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
qf.add_volume(colorChange=False)
qf.iplot(name="APPL")
# Out:
# <div>                            <div id="f747b584-de55-4b45-937a-14bb3a8701b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
qf.add_ema()
qf.iplot(name="APPL")
# Out:
# <div>                            <div id="03a11c53-6cae-47dd-8adc-b622a11b1de6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-01-02   43.075001   42.314999   42.540001   43.064999  102223600.0
# 2018-01-03   43.637501   42.990002   43.132500   43.057499  118071600.0
# 2018-01-04   43.367500   43.020000   43.134998   43.257500   89738400.0
# 2018-01-05   43.842499   43.262501   43.360001   43.750000   94640000.0
# 2018-01-08   43.902500   43.482498   43.587502   43.587502   82271200.0
# ...                ...         ...         ...         ...          ...
# 2021-05-24  127.940002  125.940002  126.010002  127.099998   63092900.0
# 2021-05-25  128.320007  126.320000  127.820000  126.900002   72009500.0
# 2021-05-26  127.389999  126.419998  126.959999  126.849998   56575900.0
# 2021-05-27  127.639999  125.080002  126.440002  125.279999   94625600.0
# 2021-05-28  125.800003  124.550003  125.570000  124.610001   71311100.0
#
#              Adj Close
# Date
# 2018-01-02   41.310070
# 2018-01-03   41.302879
# ...

# %%
import talib

# %%
output = talib.EMA(df.loc["2021"].Close, timeperiod=20)

# %%
output
# Out:
# Date
# 2021-01-04           NaN
# 2021-01-05           NaN
# 2021-01-06           NaN
# 2021-01-07           NaN
# 2021-01-08           NaN
#                  ...
# 2021-05-24    127.519023
# 2021-05-25    127.460069
# 2021-05-26    127.401967
# 2021-05-27    127.199875
# 2021-05-28    126.953220
# Length: 102, dtype: float64

# %%
# Appears to have slight difference when using talib, note from docs:
# NOTE: The EMA function has an unstable period.
# Whatever thats suppose to mean.... try to follow links to dead ends 

manual = df.Close.ewm(span=20, min_periods=20).mean()

# %%
manual
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04           NaN
# 2018-01-05           NaN
# 2018-01-08           NaN
#                  ...
# 2021-05-24    127.519390
# 2021-05-25    127.460400
# 2021-05-26    127.402267
# 2021-05-27    127.200146
# 2021-05-28    126.953465
# Name: Close, Length: 858, dtype: float64

# %%
crows = talib.CDL3BLACKCROWS(df.Open, df.High, df.Open, df.Close)

# %%
crows
# Out:
# Date
# 2018-01-02    0
# 2018-01-03    0
# 2018-01-04    0
# 2018-01-05    0
# 2018-01-08    0
#              ..
# 2021-05-24    0
# 2021-05-25    0
# 2021-05-26    0
# 2021-05-27    0
# 2021-05-28    0
# Length: 858, dtype: int32

# %%
crows.value_counts()
# Out:
#  0      856
# -100      2
# dtype: int64

# %%
df["3blackcrows"] = talib.CDL3BLACKCROWS(df.Open, df.High, df.Open, df.Close)

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-01-02   43.075001   42.314999   42.540001   43.064999  102223600.0
# 2018-01-03   43.637501   42.990002   43.132500   43.057499  118071600.0
# 2018-01-04   43.367500   43.020000   43.134998   43.257500   89738400.0
# 2018-01-05   43.842499   43.262501   43.360001   43.750000   94640000.0
# 2018-01-08   43.902500   43.482498   43.587502   43.587502   82271200.0
# ...                ...         ...         ...         ...          ...
# 2021-05-24  127.940002  125.940002  126.010002  127.099998   63092900.0
# 2021-05-25  128.320007  126.320000  127.820000  126.900002   72009500.0
# 2021-05-26  127.389999  126.419998  126.959999  126.849998   56575900.0
# 2021-05-27  127.639999  125.080002  126.440002  125.279999   94625600.0
# 2021-05-28  125.800003  124.550003  125.570000  124.610001   71311100.0
#
#              Adj Close  3blackcrows
# Date
# 2018-01-02   41.310070            0
# ...

# %%
df.loc["2021-02-01":"2021-03-01", ["Close", "3blackcrows"]].plot(figsize=(12,8), secondary_y="3blackcrows")
plt.show()

# %%
df.loc["2021", ["Open", "High", "Low", "Close", "3blackcrows"]].iplot(kind="candle", secondary_y="3blackcrows")
df.iplot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-e17b04925869> in <module>
# ----> 1 df.loc["2021", ["Open", "High", "Low", "Close", "3blackcrows"]].iplot(kind="candle", secondary_y="3blackcrows")
#       2 df.iplot()
#
# /usr/local/lib/python3.9/site-packages/cufflinks/plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...
